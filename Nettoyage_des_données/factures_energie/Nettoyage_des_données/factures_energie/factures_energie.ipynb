# %%
import pandas as pd
import numpy as np

facture = pd.read_csv("factures.csv", sep='|')

print(facture)
# Out:
#                 SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD  \
# 0      12345_GEO (0001BB)     1300082549  01/01/2018  31/01/2018      2 447
# 1      12345_GEO (0001BB)     1300082549  01/02/2018  28/02/2018      2 211
# 2      12345_GEO (0001BB)     1300082549  01/03/2018  31/03/2018      2 450
# 3      12345_GEO (0001BB)     1300082549  01/04/2018  30/04/2018      2 431
# 4      12345_GEO (0001BB)     1300082549  01/05/2018  31/05/2018      2 574
# ...                   ...            ...         ...         ...        ...
# 51427  19767_GEO (0632KO)  FV1/055100030  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO (0632KO)      055100058  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO (0632KO)      055100113  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO (0632KO)      055100168  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO (1203KO)     7220278453  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 6 columns]

# %%
facture
# Out:
#                 SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD  \
# 0      12345_GEO (0001BB)     1300082549  01/01/2018  31/01/2018      2 447
# 1      12345_GEO (0001BB)     1300082549  01/02/2018  28/02/2018      2 211
# 2      12345_GEO (0001BB)     1300082549  01/03/2018  31/03/2018      2 450
# 3      12345_GEO (0001BB)     1300082549  01/04/2018  30/04/2018      2 431
# 4      12345_GEO (0001BB)     1300082549  01/05/2018  31/05/2018      2 574
# ...                   ...            ...         ...         ...        ...
# 51427  19767_GEO (0632KO)  FV1/055100030  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO (0632KO)      055100058  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO (0632KO)      055100113  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO (0632KO)      055100168  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO (1203KO)     7220278453  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 6 columns]

# %% [markdown]
# ### 1) Le nom d'une antenne a un format bien précis : il est toujours composé de 4 chiffres et de deux lettres. On te demande de retirer tout autre caractère de la colonne "SITE_NAME".

# %%
facture['SITE_NAME'] = facture['SITE_NAME'].str[11:]

# %%
facture.head()
# Out:
#   SITE_NAME INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0   0001BB)   1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1   0001BB)   1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2   0001BB)   1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3   0001BB)   1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4   0001BB)   1300082549  01/05/2018  31/05/2018      2 574     333,37

# %%
facture['SITE_NAME']=facture['SITE_NAME'].str.replace(')','')
# Out:
# /var/folders/vy/ftxg8znx7jvfb6xqccmz028c0000gn/T/ipykernel_16768/781687647.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   facture['SITE_NAME']=facture['SITE_NAME'].str.replace(')','')

# %%
facture
# Out:
#       SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB     1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB     1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB     1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB     1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB     1300082549  01/05/2018  31/05/2018      2 574     333,37
# ...         ...            ...         ...         ...        ...        ...
# 51427    0632KO  FV1/055100030  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO      055100058  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO      055100113  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO      055100168  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO     7220278453  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 6 columns]

# %%
#clean
import re

def clean_site_name(site_name):
    result = re.search("\d{4}[a-zA-Z]{2}", site_name)
    if result is None:
        return np.NaN
    else:
        return site_name
    return resul

facture["SITE_NAME"] = [clean_site_name(site_name) for site_name in facture["SITE_NAME"]]
facture
# Out:
#       SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB     1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB     1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB     1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB     1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB     1300082549  01/05/2018  31/05/2018      2 574     333,37
# ...         ...            ...         ...         ...        ...        ...
# 51427    0632KO  FV1/055100030  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO      055100058  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO      055100113  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO      055100168  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO     7220278453  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 6 columns]

# %%
print(facture.isnull().sum())
# Out:
# SITE_NAME       11
# INVOICE_NAME     0
# BEGIN            0
# END              0
# KWH_PERIOD       0
# PERIOD_EUR       0
# dtype: int64

# %%
print(facture[facture['SITE_NAME'].isnull()])
# Out:
#       SITE_NAME INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 35919       NaN   1300082549  01/01/2018  31/01/2018      1 628     214,02
# 35920       NaN   1300082549  01/02/2018  28/02/2018      1 459     192,56
# 35921       NaN   1300082549  01/03/2018  31/03/2018      1 633     215,18
# 35922       NaN   1300082549  01/04/2018  30/04/2018      1 765     232,14
# 35923       NaN   1300082549  01/05/2018  31/05/2018      1 651     217,07
# 35924       NaN   1300082549  01/06/2018  30/06/2018      1 976     257,52
# 35925       NaN   1300082549  01/07/2018  31/07/2018      2 257     292,29
# 35926       NaN   1300082549  01/08/2018  31/08/2018      2 236     288,70
# 35927       NaN   1300082549  01/09/2018  30/09/2018        413      60,83
# 35928       NaN   1300082549  01/10/2018  31/10/2018      1 267     168,65
# 35929       NaN   1311297011  01/11/2018  28/11/2018          0       0,00

# %% [markdown]
# ### 2) On te demande de supprimer la colonne "INVOICE_NAME" qui n'apporte rien aux équipes.

# %%
del facture['INVOICE_NAME']

# %%
facture
# Out:
#       SITE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB  01/05/2018  31/05/2018      2 574     333,37
# ...         ...         ...         ...        ...        ...
# 51427    0632KO  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 5 columns]

# %% [markdown]
# ### 3) Il y a des antennes pour lesquelles on a des factures mensuelles tandis que pour d'autres, on les reçoit moins régulièrement (trimestre, semestre, année). Ajoute une colonne à ton tableau qui calcule le nombre de jours entre le début de la période de facturation et la fin de la période de facturation.

# %%
import datetime

facture['BEGIN']=pd.to_datetime(facture['BEGIN'],format='%d/%m/%Y',errors='coerce')
facture['END']=pd.to_datetime(facture['END'],format='%d/%m/%Y',errors='coerce')

facture['BETWEEN_days']=pd.Series((facture["END"].sub(facture["BEGIN"], axis=0).dt.days))

facture
# Out:
#       SITE_NAME      BEGIN        END KWH_PERIOD PERIOD_EUR  BETWEEN_days
# 0        0001BB 2018-01-01 2018-01-31      2 447     316,46            30
# 1        0001BB 2018-02-01 2018-02-28      2 211     286,82            27
# 2        0001BB 2018-03-01 2018-03-31      2 450     317,32            30
# 3        0001BB 2018-04-01 2018-04-30      2 431     315,00            29
# 4        0001BB 2018-05-01 2018-05-31      2 574     333,37            30
# ...         ...        ...        ...        ...        ...           ...
# 51427    0632KO 2019-08-30 2019-12-31      3 028     397,18           123
# 51428    0632KO 2020-01-01 2020-03-31      2 163     283,57            90
# 51429    0632KO 2020-04-01 2020-06-30      2 160     312,55            90
# 51430    0632KO 2020-07-01 2020-09-30      2 230     294,07            91
# 51431    1203KO 2019-09-27 2019-12-31      4 745     681,96            95
#
# [51432 rows x 6 columns]

# %% [markdown]
# ### 4) A partir de cette nouvelle colonne, crée une autre colonne qui nous donne la consommation journalière moyenne de la période.

# %%
print(facture['KWH_PERIOD'])
# Out:
# 0        2 447
# 1        2 211
# 2        2 450
# 3        2 431
# 4        2 574
#          ...
# 51427    3 028
# 51428    2 163
# 51429    2 160
# 51430    2 230
# 51431    4 745
# Name: KWH_PERIOD, Length: 51432, dtype: object

# %%
kwh=facture['KWH_PERIOD'].replace(' ','', regex=True).astype(float)
facture['KWH_PERIOD']=kwh
print(facture['KWH_PERIOD'])
# Out:
# 0        2447.0
# 1        2211.0
# 2        2450.0
# 3        2431.0
# 4        2574.0
#           ...
# 51427    3028.0
# 51428    2163.0
# 51429    2160.0
# 51430    2230.0
# 51431    4745.0
# Name: KWH_PERIOD, Length: 51432, dtype: float64

# %%
facture["KWH_DAYS"] = facture.apply(lambda x: "NaN" if x['BETWEEN_days'] <= 0 else x["KWH_PERIOD"]/x['BETWEEN_days'], axis=1)
facture
# Out:
#       SITE_NAME      BEGIN        END  KWH_PERIOD PERIOD_EUR  BETWEEN_days  \
# 0        0001BB 2018-01-01 2018-01-31      2447.0     316,46            30
# 1        0001BB 2018-02-01 2018-02-28      2211.0     286,82            27
# 2        0001BB 2018-03-01 2018-03-31      2450.0     317,32            30
# 3        0001BB 2018-04-01 2018-04-30      2431.0     315,00            29
# 4        0001BB 2018-05-01 2018-05-31      2574.0     333,37            30
# ...         ...        ...        ...         ...        ...           ...
# 51427    0632KO 2019-08-30 2019-12-31      3028.0     397,18           123
# 51428    0632KO 2020-01-01 2020-03-31      2163.0     283,57            90
# 51429    0632KO 2020-04-01 2020-06-30      2160.0     312,55            90
# 51430    0632KO 2020-07-01 2020-09-30      2230.0     294,07            91
# 51431    1203KO 2019-09-27 2019-12-31      4745.0     681,96            95
#
#         KWH_DAYS
# 0      81.566667
# 1      81.888889
# 2      81.666667
# 3      83.827586
# 4           85.8
# ...          ...
# 51427  24.617886
# 51428  24.033333
# 51429       24.0
# 51430  24.505495
# 51431  49.947368
#
# [51432 rows x 7 columns]

# %% [markdown]
# ### 5) Merci d'ajouter également une colonne qui donne, pour chaque antenne, le nombre de factures dont on dispose au total. Pas grave si l'information se répète à chaque ligne pour une même antenne.

# %%
facture['NB_FACTURES'] = facture.groupby(['SITE_NAME'])['SITE_NAME'].transform('size')
facture
# Out:
#       SITE_NAME      BEGIN        END  KWH_PERIOD PERIOD_EUR  BETWEEN_days  \
# 0        0001BB 2018-01-01 2018-01-31      2447.0     316,46            30
# 1        0001BB 2018-02-01 2018-02-28      2211.0     286,82            27
# 2        0001BB 2018-03-01 2018-03-31      2450.0     317,32            30
# 3        0001BB 2018-04-01 2018-04-30      2431.0     315,00            29
# 4        0001BB 2018-05-01 2018-05-31      2574.0     333,37            30
# ...         ...        ...        ...         ...        ...           ...
# 51427    0632KO 2019-08-30 2019-12-31      3028.0     397,18           123
# 51428    0632KO 2020-01-01 2020-03-31      2163.0     283,57            90
# 51429    0632KO 2020-04-01 2020-06-30      2160.0     312,55            90
# 51430    0632KO 2020-07-01 2020-09-30      2230.0     294,07            91
# 51431    1203KO 2019-09-27 2019-12-31      4745.0     681,96            95
#
#         KWH_DAYS  NB_FACTURES
# 0      81.566667         35.0
# 1      81.888889         35.0
# 2      81.666667         35.0
# 3      83.827586         35.0
# 4           85.8         35.0
# ...          ...          ...
# 51427  24.617886          4.0
# 51428  24.033333          4.0
# 51429       24.0          4.0
# 51430  24.505495          4.0
# 51431  49.947368          1.0
#
# [51432 rows x 8 columns]

# %% [markdown]
# ### 6) Et information bonus si tu y arrives : les équipes aimeraient beaucoup avoir une liste de toutes les antennes avec, pour chaque antenne, le coefficient de variation de la consommation. Cela permettra d'avoir une idée, pour chaque antenne, de la dispersion de sa consommation d'énergie.

# %% [markdown]
# ### 7) Enfin, tu dois exporter ces deux fichiers obtenus pour pouvoir l'envoyer aux équipes de l'opérateur et leur demander si c'est bien cela qu'ils attendaient de toi.

# %%
facture.to_csv('/Users/macameline/Documents/learn_code/THP_DATA/sem2_/Nettoyage_des_données/factures_energie/facture_clean.csv')
